# %%
ls =!ls /dev
ls

# %%
import mindwave
import time

headset = mindwave.Headset('/dev/tty.MindWaveMobile-SerialPo','MMPPHB2013')
time.sleep(2)
headset.autoconnect()

print ("Connecting...")

while headset.status != ('connected'):
    print "before time"
    time.sleep(0.5)
    print(headset.status)
    if headset.status == ('standby'):
        print "haha"
        headset.autoconnect()
        print ("Retrying connect...")
    if headset.status == None:
        print(headset.attention, headset.meditation)
print ("Connected.")

while True:
    print ("Attention: %s, Meditation: %s") (headset.attention, headset.meditation)
# Out:
# Connecting...
# before time
# None
# (61, 60)
# before time
# None
# (61, 60)
# before time
# None
# (66, 66)
# before time
# None
# (66, 66)
# before time
# None
# (56, 57)
# before time
# None
# (56, 57)
# before time
# None
# (53, 47)
# before time
# None
# (47, 26)
# before time
# None
# (47, 26)
# before time
# None
# (48, 30)
# before time
# None
# (48, 30)
# before time
# None
# (57, 38)
# before time
# None
# (57, 38)
# before time
# None
# (60, 44)
# before time
# None
# (60, 44)
# before time
# None
# (66, 56)
# before time
# None
# (66, 56)
# before time
# None
# (61, 48)
# before time
# None
# (61, 48)
# before time
# None
# (51, 41)
# before time
# None
# (51, 41)
# before time
# None
# (50, 41)
# before time
# None
# (50, 41)
# before time
# None
# (34, 38)
# before time
# None
# (34, 38)
# before time
# None
# (26, 51)
# before time
# None
# (26, 51)
# before time
# None
# (37, 56)
# before time
# None
# (37, 56)
# before time
# None
# (40, 51)
# before time
# None
# (40, 51)
# before time
# None
# (37, 40)
# before time
# None
# (37, 40)
# before time
# None
# (37, 29)
# before time
# None
# (37, 29)
# before time
# None
# (35, 20)
# before time
# None
# (35, 20)
# before time
# None
# (35, 34)
# before time
# None
# (35, 34)
# before time
# None
# (43, 41)
# before time
# None
# (43, 41)
# before time
# None
# (48, 47)
# before time
# None
# (48, 47)
# before time
# None
# (34, 47)
# before time
# None
# (34, 47)
# before time
# None
# (29, 47)
# before time
# None
# (29, 47)
# before time
# None
# (30, 50)
# before time
# None
# (30, 50)
# before time
# None
# (29, 44)
# before time
# None
# (29, 44)
# before time
# None
# (41, 43)
# before time
# None
# (41, 43)
# before time
# None
# (43, 37)
# before time
# None
# (43, 37)
# before time
# None
# (43, 38)
# before time
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-c889828835d9> in <module>()
#      11 while headset.status != ('connected'):
#      12     print "before time"
# ---> 13     time.sleep(0.5)
#      14     print(headset.status)
#      15     if headset.status == ('standby'):
#
# KeyboardInterrupt:
